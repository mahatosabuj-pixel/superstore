# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/superstore_messy_dataset.csv')

# %%
data
# Out:
#        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0         ORD-1  2021-04-13  2023-08-14  Standard Class   CUST-5510
# 1         ORD-2  2022-03-12  2021-10-08  Standard Class   CUST-1393
# 2         ORD-3  2023-05-11  2021-09-10  Standard Class   CUST-9005
# 3         ORD-4  2021-09-28  2021-11-08     First Class   CUST-4686
# 4         ORD-5  2021-04-17  2022-12-23     First Class   CUST-1357
# ...         ...         ...         ...             ...         ...
# 10195  ORD-8954  2022-10-27  2021-12-01     First Class   CUST-3508
# 10196  ORD-4922  2022-01-05  2022-05-06    Second Class   CUST-7345
# 10197  ORD-5512  2022-09-05  2021-03-10     First Class   CUST-9151
# 10198  ORD-2620  2021-01-24  2021-04-30     First Class   CUST-9805
# 10199  ORD-1114  2021-12-01  2023-09-29  Standard Class   CUST-9572
#
#       Customer Name      Segment Country       City State Region Product ID  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10200 entries, 0 to 10199
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       10200 non-null  object
#  1   Order Date     10200 non-null  object
#  2   Ship Date      10200 non-null  object
#  3   Ship Mode      10200 non-null  object
#  4   Customer ID    10200 non-null  object
#  5   Customer Name  10200 non-null  object
#  6   Segment        10200 non-null  object
#  7   Country        10200 non-null  object
#  8   City           9687 non-null   object
#  9   State          10200 non-null  object
#  10  Region         10200 non-null  object
#  11  Product ID     10200 non-null  object
#  12  Category       10200 non-null  object
#  13  Sub-Category   10200 non-null  object
#  14  Product Name   10200 non-null  object
#  15  Sales          9690 non-null   float64
#  16  Quantity       10200 non-null  int64
# ...

# %%
data.duplicated().any()
# Out:
# np.True_

# %%
data.duplicated().sum ()
# Out:
# np.int64(196)

# %%
data.isnull().sum()
# Out:
# Order ID           0
# Order Date         0
# Ship Date          0
# Ship Mode          0
# Customer ID        0
# Customer Name      0
# Segment            0
# Country            0
# City             513
# State              0
# Region             0
# Product ID         0
# Category           0
# Sub-Category       0
# Product Name       0
# Sales            510
# Quantity           0
# Discount         509
# Profit           514
# dtype: int64

# %%
data.describe()
# Out:
#              Sales      Quantity     Discount       Profit
# count  9690.000000  10200.000000  9691.000000  9686.000000
# mean   2545.628851      4.966961     0.251417  -130.549307
# std    1431.455178      2.571687     0.144310   429.654109
# min      50.890000      1.000000     0.000000 -1519.240000
# 25%    1291.402500      3.000000     0.120000  -377.815000
# 50%    2570.385000      5.000000     0.250000   -75.060000
# 75%    3805.920000      7.000000     0.370000   122.482500
# max    4999.340000      9.000000     0.500000  1068.880000

# %%
#remove all duplicates value from data permanently

data.drop_duplicates(inplace=True)

# %%
numarical={'Sales','Discount','Profit'}
for i in categorical:
  data[i].fillna(data[i].median(),inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13451/3417541455.py in <cell line: 0>()
#       1 numarical={'Sales','Discount','Profit'}
# ----> 2 for i in categorical:
#       3   data[i].fillna(data[i].median(),inplace=True)
#
# NameError: name 'categorical' is not defined

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10004 entries, 0 to 10157
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       10004 non-null  object
#  1   Order Date     10004 non-null  object
#  2   Ship Date      10004 non-null  object
#  3   Ship Mode      10004 non-null  object
#  4   Customer ID    10004 non-null  object
#  5   Customer Name  10004 non-null  object
#  6   Segment        10004 non-null  object
#  7   Country        10004 non-null  object
#  8   City           9504 non-null   object
#  9   State          10004 non-null  object
#  10  Region         10004 non-null  object
#  11  Product ID     10004 non-null  object
#  12  Category       10004 non-null  object
#  13  Sub-Category   10004 non-null  object
#  14  Product Name   10004 non-null  object
#  15  Sales          9504 non-null   float64
#  16  Quantity       10004 non-null  int64
# ...

# %%
data['City'].fillna(data['City'].mode()[0],inplace=True)
# Out:
# /tmp/ipykernel_13451/3489286642.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['City'].fillna(data['City'].mode()[0],inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10004 entries, 0 to 10157
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       10004 non-null  object
#  1   Order Date     10004 non-null  object
#  2   Ship Date      10004 non-null  object
#  3   Ship Mode      10004 non-null  object
#  4   Customer ID    10004 non-null  object
#  5   Customer Name  10004 non-null  object
#  6   Segment        10004 non-null  object
#  7   Country        10004 non-null  object
#  8   City           10004 non-null  object
#  9   State          10004 non-null  object
#  10  Region         10004 non-null  object
#  11  Product ID     10004 non-null  object
#  12  Category       10004 non-null  object
#  13  Sub-Category   10004 non-null  object
#  14  Product Name   10004 non-null  object
#  15  Sales          9504 non-null   float64
#  16  Quantity       10004 non-null  int64
# ...

# %%
data
# Out:
#         Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0          ORD-1  2021-04-13  2023-08-14  Standard Class   CUST-5510
# 1          ORD-2  2022-03-12  2021-10-08  Standard Class   CUST-1393
# 2          ORD-3  2023-05-11  2021-09-10  Standard Class   CUST-9005
# 3          ORD-4  2021-09-28  2021-11-08     First Class   CUST-4686
# 4          ORD-5  2021-04-17  2022-12-23     First Class   CUST-1357
# ...          ...         ...         ...             ...         ...
# 9999   ORD-10000  2021-10-02  2022-08-09  Standard Class   CUST-1459
# 10028   ORD-8013  2021-10-12  2022-10-16    Second Class   CUST-5751
# 10078   ORD-7580  2022-06-08  2023-09-11    Second Class   CUST-1130
# 10119   ORD-8378  2022-12-01  2023-05-20    Second Class   CUST-3122
# 10157   ORD-1250  2021-08-02  2021-05-22  Standard Class   CUST-7323
#
#       Customer Name      Segment Country       City State Region Product ID  \
# ...

# %%
data['Order Date']=pd.to_datetime(data['Order Date'])

# %%
data['Ship Date']=pd.to_datetime(data['Ship Date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10004 entries, 0 to 10157
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       10004 non-null  object
#  1   Order Date     10004 non-null  datetime64[ns]
#  2   Ship Date      10004 non-null  datetime64[ns]
#  3   Ship Mode      10004 non-null  object
#  4   Customer ID    10004 non-null  object
#  5   Customer Name  10004 non-null  object
#  6   Segment        10004 non-null  object
#  7   Country        10004 non-null  object
#  8   City           10004 non-null  object
#  9   State          10004 non-null  object
#  10  Region         10004 non-null  object
#  11  Product ID     10004 non-null  object
#  12  Category       10004 non-null  object
#  13  Sub-Category   10004 non-null  object
#  14  Product Name   10004 non-null  object
#  15  Sales          9504 non-null   float64
#  16  Quantity       10004 non-null  int64
# ...

# %%
data['Month']=data['Order Date'].dt.month

# %%
data
# Out:
#         Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0          ORD-1 2021-04-13 2023-08-14  Standard Class   CUST-5510
# 1          ORD-2 2022-03-12 2021-10-08  Standard Class   CUST-1393
# 2          ORD-3 2023-05-11 2021-09-10  Standard Class   CUST-9005
# 3          ORD-4 2021-09-28 2021-11-08     First Class   CUST-4686
# 4          ORD-5 2021-04-17 2022-12-23     First Class   CUST-1357
# ...          ...        ...        ...             ...         ...
# 9999   ORD-10000 2021-10-02 2022-08-09  Standard Class   CUST-1459
# 10028   ORD-8013 2021-10-12 2022-10-16    Second Class   CUST-5751
# 10078   ORD-7580 2022-06-08 2023-09-11    Second Class   CUST-1130
# 10119   ORD-8378 2022-12-01 2023-05-20    Second Class   CUST-3122
# 10157   ORD-1250 2021-08-02 2021-05-22  Standard Class   CUST-7323
#
#       Customer Name      Segment Country       City State Region Product ID  \
# 0             Rahul    Corporate   India      Delhi    WB  North   PROD-420
# ...

# %%
data['year']=data['Order Date'].dt.year

# %%
data
# Out:
#         Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0          ORD-1 2021-04-13 2023-08-14  Standard Class   CUST-5510
# 1          ORD-2 2022-03-12 2021-10-08  Standard Class   CUST-1393
# 2          ORD-3 2023-05-11 2021-09-10  Standard Class   CUST-9005
# 3          ORD-4 2021-09-28 2021-11-08     First Class   CUST-4686
# 4          ORD-5 2021-04-17 2022-12-23     First Class   CUST-1357
# ...          ...        ...        ...             ...         ...
# 9999   ORD-10000 2021-10-02 2022-08-09  Standard Class   CUST-1459
# 10028   ORD-8013 2021-10-12 2022-10-16    Second Class   CUST-5751
# 10078   ORD-7580 2022-06-08 2023-09-11    Second Class   CUST-1130
# 10119   ORD-8378 2022-12-01 2023-05-20    Second Class   CUST-3122
# 10157   ORD-1250 2021-08-02 2021-05-22  Standard Class   CUST-7323
#
#       Customer Name      Segment Country       City State  ... Product ID  \
# 0             Rahul    Corporate   India      Delhi    WB  ...   PROD-420
# ...

# %%
data['profit margin']=data['Profit']/data['Sales']

# %%
data['sales category']=pd.cut(data['Sales'],
                              bins=[0,100,500,1000,5000],
                              labels=['low','medium','high','very high'])

# %%
data
# Out:
#         Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0          ORD-1 2021-04-13 2023-08-14  Standard Class   CUST-5510
# 1          ORD-2 2022-03-12 2021-10-08  Standard Class   CUST-1393
# 2          ORD-3 2023-05-11 2021-09-10  Standard Class   CUST-9005
# 3          ORD-4 2021-09-28 2021-11-08     First Class   CUST-4686
# 4          ORD-5 2021-04-17 2022-12-23     First Class   CUST-1357
# ...          ...        ...        ...             ...         ...
# 9999   ORD-10000 2021-10-02 2022-08-09  Standard Class   CUST-1459
# 10028   ORD-8013 2021-10-12 2022-10-16    Second Class   CUST-5751
# 10078   ORD-7580 2022-06-08 2023-09-11    Second Class   CUST-1130
# 10119   ORD-8378 2022-12-01 2023-05-20    Second Class   CUST-3122
# 10157   ORD-1250 2021-08-02 2021-05-22  Standard Class   CUST-7323
#
#       Customer Name      Segment Country       City State  ... Sub-Category  \
# 0             Rahul    Corporate   India      Delhi    WB  ...       Chairs
# ...

# %%
#which catagori has the highest total sales?
#which catagori gives most profitable?
#how many nagetive trasaction they have
#monthly sales treand
#which customer segments contributs most in sales?
#which city genarate highest sales?
#profit by regions
#sales catagori distribution

# %%
data.to_csv('clean superstore.csv',index=False)
